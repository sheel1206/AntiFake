# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
pagesToGet= 37

upperframe=[]  
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.politifact.com/factchecks/list/?page='+str(page) + "&category=coronavirus"
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('li',attrs={'class':'o-listicle__item'})
    print(len(links))
    filename="NEWS.csv"
    f=open(filename,"w", encoding = 'utf-8')
    headers="Statement,Link,Date, Source, Label\n"
    f.write(headers)
    
    for j in links:
        Statement = j.find("div",attrs={'class':'m-statement__quote'}).text.strip()
        Link = "https://www.politifact.com/factchecks/list/?category=coronavirus"
        Link += j.find("div",attrs={'class':'m-statement__quote'}).find('a')['href'].strip()
        Date = j.find('div',attrs={'class':'m-statement__body'}).find('footer').text[-14:-1].strip()
        Source = j.find('div', attrs={'class':'m-statement__meta'}).find('a').text.strip()
        Label = j.find('div', attrs ={'class':'m-statement__content'}).find('img',attrs={'class':'c-image__original'}).get('alt').strip()
        frame.append((Statement,Link,Date,Source,Label))
        f.write(Statement.replace(",","^")+","+Link+","+Date.replace(",","^")+","+Source.replace(",","^")+","+Label.replace(",","^")+"\n")
    upperframe.extend(frame)
# Out:
# processing page : 1
# https://www.politifact.com/factchecks/list/?page=1&category=coronavirus
# 30
# processing page : 2
# https://www.politifact.com/factchecks/list/?page=2&category=coronavirus
# 30
# processing page : 3
# https://www.politifact.com/factchecks/list/?page=3&category=coronavirus
# 30
# processing page : 4
# https://www.politifact.com/factchecks/list/?page=4&category=coronavirus
# 30
# processing page : 5
# https://www.politifact.com/factchecks/list/?page=5&category=coronavirus
# 30
# processing page : 6
# https://www.politifact.com/factchecks/list/?page=6&category=coronavirus
# 30
# processing page : 7
# https://www.politifact.com/factchecks/list/?page=7&category=coronavirus
# 30
# processing page : 8
# https://www.politifact.com/factchecks/list/?page=8&category=coronavirus
# 30
# processing page : 9
# https://www.politifact.com/factchecks/list/?page=9&category=coronavirus
# 30
# processing page : 10
# ...

# %%
f.close()
data=pd.DataFrame(upperframe, columns=['Statement','Link','Date','Source','Label'])
data.head(-5)
# Out:
#                                               Statement  \
# 0     “There are precious few religions that actuall...
# 1     “We do not have an approved (COVID) vaccine in...
# 2     "New data shows that death is proportional to ...
# 3     “If you look at the hospitalizations at Ruby M...
# 4     Says 86% of COVID-19 cases in Israel in July w...
# ...                                                 ...
# 1069  “Cocaine kills corona virus, scientists is sho...
# 1070  Says "the coronavirus was engineered by scient...
# 1071  Says the coronavirus isn’t new because “Lysol ...
# 1072  Event 201 “gave out stuffed souvenir coronavir...
# 1073  Says drinking a bleach solution will prevent y...
#
#                                                    Link           Date  \
# 0     https://www.politifact.com/factchecks/list/?ca...  tober 6, 2021
# 1     https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 2     https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# ...

# %%
data[data['Label']==1].count()
# Out:
# Statement    127
# Link         127
# Date         127
# Source       127
# Label        127
# dtype: int64

# %%
for i in range(len(data)):
    if(data['Label'][i] == 'true' or data['Label'][i] == 'mostly-true'):
        data['Label'][i] = 1
    else:
        data['Label'][i] = 0

# %%
data.head()
# Out:
#                                            Statement  \
# 0  “There are precious few religions that actuall...
# 1  “We do not have an approved (COVID) vaccine in...
# 2  "New data shows that death is proportional to ...
# 3  “If you look at the hospitalizations at Ruby M...
# 4  Says 86% of COVID-19 cases in Israel in July w...
#
#                                                 Link           Date  \
# 0  https://www.politifact.com/factchecks/list/?ca...  tober 6, 2021
# 1  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 2  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 3  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 4  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
#
#                      Source Label
# 0             Anthony Fauci     1
# 1               Ron Johnson     0
# 2           Instagram posts     0
# 3  Kathryn Moffett Bradford     1
# 4              TikTok posts     0

# %%
data.to_csv(r'NEWS.csv')
