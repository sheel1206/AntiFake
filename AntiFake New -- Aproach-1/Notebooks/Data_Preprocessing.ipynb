# %%
import pandas as pd

# %%
true = pd.read_csv(r'C:\Users\SHEEL\Desktop\IXXO\defensecommune_ai\Data\trueNews.csv')
fake = pd.read_csv(r'C:\Users\SHEEL\Desktop\IXXO\defensecommune_ai\Data\fakeNews.csv')

# %%
true.shape
# Out:
# (3793, 7)

# %%
true.head()
# Out:
#   Date Posted                                               Link  \
# 0     2/11/20  https://twitter.com/the_hindu/status/122725962...
# 1     2/12/20  https://twitter.com/ndtv/status/12274908434742...
# 2     2/12/20  https://twitter.com/the_hindu/status/122744471...
# 3     2/14/20  https://twitter.com/IndiaToday/status/12282764...
# 4     2/15/20  https://twitter.com/the_hindu/status/122854247...
#
#                                                 Text Region    Username  \
# 0  Just in: Novel coronavirus named 'Covid-19': U...  India   the_hindu
# 1  WHO officially names #coronavirus as Covid-19....  India        ndtv
# 2  The #UN #health agency announced that "COVID-1...  India   the_hindu
# 3  The Indian Embassy in Tokyo has said that one ...  India  indiatoday
# 4  Ground Zero | How Kerala used its experience i...  India   the_hindu
#
#     Publisher  Label
# 0   The Hindu      1
# 1        NDTV      1
# 2   The Hindu      1
# 3  IndiaToday      1
# 4   The Hindu      1

# %%
true = true.drop(['Publisher'], axis = 1)

# %%
true = true.drop(['Username'], axis = 1)

# %%
true.head()
# Out:
#   Date Posted                                               Link  \
# 0     2/11/20  https://twitter.com/the_hindu/status/122725962...
# 1     2/12/20  https://twitter.com/ndtv/status/12274908434742...
# 2     2/12/20  https://twitter.com/the_hindu/status/122744471...
# 3     2/14/20  https://twitter.com/IndiaToday/status/12282764...
# 4     2/15/20  https://twitter.com/the_hindu/status/122854247...
#
#                                                 Text Region  Label
# 0  Just in: Novel coronavirus named 'Covid-19': U...  India      1
# 1  WHO officially names #coronavirus as Covid-19....  India      1
# 2  The #UN #health agency announced that "COVID-1...  India      1
# 3  The Indian Embassy in Tokyo has said that one ...  India      1
# 4  Ground Zero | How Kerala used its experience i...  India      1

# %%
fake.head()
# Out:
#   Date Posted                                               Link  \
# 0      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 1      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 2      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 3      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 4      2/7/20  https://www.poynter.org/?ifcn_misinformation=c...
#
#                                                 Text  Region   Country  \
# 0    Tencent revealed the real number of deaths.\t\t  Europe    France
# 1   Taking chlorine dioxide helps fight coronavir...  Europe   Germany
# 2   This video shows workmen uncovering a bat-inf...   India     India
# 3   The Asterix comic books and The Simpsons pred...   India     India
# 4   Chinese President Xi Jinping visited a mosque...   India     India
#
#                                          Explanation     Origin  \
# 0                    The screenshot is questionable.    Twitter
# ...

# %%
fake = fake.drop(['Country'], axis = 1)
fake = fake.drop(['Explanation'], axis = 1)
fake = fake.drop(['Origin'], axis = 1)
fake = fake.drop(['Origin_URL'], axis = 1)
fake = fake.drop(['Fact_checked_by'], axis = 1)
#fake = fake.drop(['Poynter_Label'], axis = 1)

# %%
fake = fake.rename(columns={'Binary Label':'Label'})

# %%
fake.head()
# Out:
#   Date Posted                                               Link  \
# 0      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 1      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 2      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 3      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 4      2/7/20  https://www.poynter.org/?ifcn_misinformation=c...
#
#                                                 Text  Region  Label
# 0    Tencent revealed the real number of deaths.\t\t  Europe      0
# 1   Taking chlorine dioxide helps fight coronavir...  Europe      0
# 2   This video shows workmen uncovering a bat-inf...   India      0
# 3   The Asterix comic books and The Simpsons pred...   India      0
# 4   Chinese President Xi Jinping visited a mosque...   India      0

# %%
final_df =  true.append(fake)

# %%
final_df.head()
# Out:
#   Date Posted                                               Link  \
# 0     2/11/20  https://twitter.com/the_hindu/status/122725962...
# 1     2/12/20  https://twitter.com/ndtv/status/12274908434742...
# 2     2/12/20  https://twitter.com/the_hindu/status/122744471...
# 3     2/14/20  https://twitter.com/IndiaToday/status/12282764...
# 4     2/15/20  https://twitter.com/the_hindu/status/122854247...
#
#                                                 Text Region  Label
# 0  Just in: Novel coronavirus named 'Covid-19': U...  India      1
# 1  WHO officially names #coronavirus as Covid-19....  India      1
# 2  The #UN #health agency announced that "COVID-1...  India      1
# 3  The Indian Embassy in Tokyo has said that one ...  India      1
# 4  Ground Zero | How Kerala used its experience i...  India      1

# %%
#final_df= final_df.drop(['Date Posted'], axis = 1)
#final_df=final_df.drop(['Link'], axis = 1)
#final_df=final_df.drop(['Region'], axis = 1)

# %%
final_df = pd.read_csv(r'C:\Users\SHEEL\Desktop\IXXO\defensecommune_ai\Data\final_data.csv')

# %%
df2 = pd.read_csv(r'C:\Users\SHEEL\Desktop\IXXO\defensecommune_ai\NEWS.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0                                          Statement  \
# 0           0  “There are precious few religions that actuall...
# 1           1  “We do not have an approved (COVID) vaccine in...
# 2           2  "New data shows that death is proportional to ...
# 3           3  “If you look at the hospitalizations at Ruby M...
# 4           4  Says 86% of COVID-19 cases in Israel in July w...
#
#                                                 Link           Date  \
# 0  https://www.politifact.com/factchecks/list/?ca...  tober 6, 2021
# 1  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 2  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 3  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
# 4  https://www.politifact.com/factchecks/list/?ca...  tober 5, 2021
#
#                      Source  Label
# 0             Anthony Fauci      1
# 1               Ron Johnson      0
# 2           Instagram posts      0
# ...

# %%
final_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Date Posted  \
# 0           0             0     2/11/20
# 1           1             1     2/12/20
# 2           2             2     2/12/20
# 3           3             3     2/14/20
# 4           4             4     2/15/20
#
#                                                 Link  \
# 0  https://twitter.com/the_hindu/status/122725962...
# 1  https://twitter.com/ndtv/status/12274908434742...
# 2  https://twitter.com/the_hindu/status/122744471...
# 3  https://twitter.com/IndiaToday/status/12282764...
# 4  https://twitter.com/the_hindu/status/122854247...
#
#                                                 Text  Label
# 0  Just in: Novel coronavirus named 'Covid-19': U...      1
# 1  WHO officially names #coronavirus as Covid-19....      1
# 2  The #UN #health agency announced that "COVID-1...      1
# 3  The Indian Embassy in Tokyo has said that one ...      1
# 4  Ground Zero | How Kerala used its experience i...      1

# %%
df2 = df2.rename(columns={'Date':'Date Posted','Statement':'Text'})
df2 = df2.drop(['Source'], axis = 1)
final_df = final_df.drop(['Region'], axis = 1)

# %%
final_df = final_df.append(df2)

# %%
final_df.shape
# Out:
# (8667, 5)

# %%
final_df.head()
# Out:
#    Unnamed: 0 Date Posted                                               Link  \
# 0           0     2/11/20  https://twitter.com/the_hindu/status/122725962...
# 1           1     2/12/20  https://twitter.com/ndtv/status/12274908434742...
# 2           2     2/12/20  https://twitter.com/the_hindu/status/122744471...
# 3           3     2/14/20  https://twitter.com/IndiaToday/status/12282764...
# 4           4     2/15/20  https://twitter.com/the_hindu/status/122854247...
#
#                                                 Text  Label
# 0  Just in: Novel coronavirus named 'Covid-19': U...      1
# 1  WHO officially names #coronavirus as Covid-19....      1
# 2  The #UN #health agency announced that "COVID-1...      1
# 3  The Indian Embassy in Tokyo has said that one ...      1
# 4  Ground Zero | How Kerala used its experience i...      1

# %%
final_df.to_csv(r'final_data.csv')
